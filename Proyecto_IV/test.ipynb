# %%
import pandas as pd

# %%
df = pd.read_csv('PROFECO_2015_vEspecial.csv', encoding='latin1')

# %%
df.head()
# Out:
#     AÑO UNIDAD ADMINISTRATIVA NUMERO DE EXPEDIENTE DE VERIFICACION  \
# 0  2015        AGUASCALIENTES                      702/000009/2015
# 1  2015        AGUASCALIENTES                      702/000012/2015
# 2  2015        AGUASCALIENTES                      702/000132/2015
# 3  2015        AGUASCALIENTES                      702/000133/2015
# 4  2015        AGUASCALIENTES                      702/000134/2015
#
#   FECHA DE VISITA NORMA OFICIAL MEXICANA VERIFICADA TIPO DE PRODUCTO  \
# 0      2015-01-05                 NOM-015-SCFI-2007          MUÑECOS
# 1      2015-01-06                 NOM-004-SCFI-2006   ROPA CABALLERO
# 2      2015-02-12                 NOM-142-SSA1-1995           BRANDY
# 3      2015-02-12                 NOM-142-SSA1-1995           BRANDY
# 4      2015-02-12                 NOM-142-SSA1-1995           BRANDY
#
#                             DESCRIPCION DEL PRODUCTO  \
# 0  EN EMPAQUE DE CARTON ESTAMPADO Y PLASTICO RIGI...
# ...

# %%
len(df['TIPO DE PRODUCTO'].unique())
# Out:
# 323

# %%
len(df)-len(df['DESCRIPCION DEL PRODUCTO'].unique())
# Out:
# 3728

# %%
len(df['DESCRIPCION DEL PRODUCTO'].unique())
# Out:
# 27486

# %%
df.columns
# Out:
# Index(['AÑO', 'UNIDAD ADMINISTRATIVA', 'NUMERO DE EXPEDIENTE DE VERIFICACION',
#        'FECHA DE VISITA', 'NORMA OFICIAL MEXICANA VERIFICADA',
#        'TIPO DE PRODUCTO', 'DESCRIPCION DEL PRODUCTO', 'RAZON SOCIAL VISITADA',
#        'GIRO COMERCIAL', 'MUNICIPIO', 'ENTIDAD', 'INCUMPLIMIENTO',
#        'CLASIFICACION RESULTADO PRODUCTO'],
#       dtype='object')

# %%
df_clean = df[['TIPO DE PRODUCTO', 'DESCRIPCION DEL PRODUCTO', 'RAZON SOCIAL VISITADA', 'GIRO COMERCIAL', 'MUNICIPIO', 'ENTIDAD', 'INCUMPLIMIENTO']]

# %%
df_clean.head()
# Out:
#   TIPO DE PRODUCTO                           DESCRIPCION DEL PRODUCTO  \
# 0          MUÑECOS  EN EMPAQUE DE CARTON ESTAMPADO Y PLASTICO RIGI...
# 1   ROPA CABALLERO  CAMISA PARA CABALLERO EN COLOR AZUL MARINO DE ...
# 2           BRANDY  UNA BOTELLA BRANDY DE LA MARCA TORRES 10 CON L...
# 3           BRANDY  ENVASE DE VIDRIO CONTENIDO BRANDY DE LA MARCA ...
# 4           BRANDY  BOTELLA DE VIDRIO CONTENIDO BRANDY 100% UVA GR...
#
#                                RAZON SOCIAL VISITADA        GIRO COMERCIAL  \
# 0              JULIO CEPEDA JUGUETERIAS S.A. DE C.V.            JUGUETERIA
# 1                           C&A DE MEXICO S. DE R.L.  TIENDA DEPARTAMENTAL
# 2                             ASFEIXAS  S.A. DE C.V.                 MOTEL
# 3     MOTEL VILLA MIRO- MIRO HOTELERIA  S.A. DE C.V.                 MOTEL
# 4  MOTEL LUA- COMPAÑIA HOTELERA PESCADORES  S.A. ...                 MOTEL
#
#         MUNICIPIO         ENTIDAD                INCUMPLIMIENTO
# ...

# %%
#Hay duplicados en los datos originales
df_clean.duplicated().sum()
# Out:
# 823

# %%
df_clean.drop_duplicates(inplace=True)
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df_clean['INCUMPLIMIENTO'].unique()
# Out:
# array(['NO SE DETECTO INCUMPLIMIENTO',
#        'Carece de la informacion comercial obligatoria',
#        'Producto Caducado', 'Carece de fecha de caducidad',
#        'Carece del precio maximo al publico en caracteres legibles e indelebles.',
#        'Carece de la lista de ingredientes',
#        'Carece de nombre y domicilio fiscal del fabricante o importador',
#        'Carece del nombre o denominacion generica del producto',
#        'Carece de toda informacion comercial  en el producto',
#        'Ostenta el Pais de Origen en Idioma Distinto al Espa¤ol',
#        'No indica veracidad de la informaci¢n comercial',
#        'Ostenta la informaci¢n comercial en idioma distinto al Espa¤ol',
#        'La informaci¢n  nutrimental  se encuentra en otro idioma distinto al espa¤ol',
#        'Induce a error o confusion al consumidor con respecto a la naturaleza y caracteristicas del producto',
#        'Carece de leyenda : No etiquetado para su venta Individual',
# ...

# %%
df_clean['CUMPLIO?'] = df_clean['INCUMPLIMIENTO'].apply(lambda x: str(x) == 'NO SE DETECTO INCUMPLIMIENTO')
# Out:
# C:\Users\yeudi\AppData\Local\Temp/ipykernel_4588/3885365378.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['CUMPLIO?'] = df_clean['INCUMPLIMIENTO'].apply(lambda x: str(x) == 'NO SE DETECTO INCUMPLIMIENTO')

# %%
df_clean.head()
# Out:
#   TIPO DE PRODUCTO                           DESCRIPCION DEL PRODUCTO  \
# 0          MUÑECOS  EN EMPAQUE DE CARTON ESTAMPADO Y PLASTICO RIGI...
# 1   ROPA CABALLERO  CAMISA PARA CABALLERO EN COLOR AZUL MARINO DE ...
# 2           BRANDY  UNA BOTELLA BRANDY DE LA MARCA TORRES 10 CON L...
# 3           BRANDY  ENVASE DE VIDRIO CONTENIDO BRANDY DE LA MARCA ...
# 4           BRANDY  BOTELLA DE VIDRIO CONTENIDO BRANDY 100% UVA GR...
#
#                                RAZON SOCIAL VISITADA        GIRO COMERCIAL  \
# 0              JULIO CEPEDA JUGUETERIAS S.A. DE C.V.            JUGUETERIA
# 1                           C&A DE MEXICO S. DE R.L.  TIENDA DEPARTAMENTAL
# 2                             ASFEIXAS  S.A. DE C.V.                 MOTEL
# 3     MOTEL VILLA MIRO- MIRO HOTELERIA  S.A. DE C.V.                 MOTEL
# 4  MOTEL LUA- COMPAÑIA HOTELERA PESCADORES  S.A. ...                 MOTEL
#
#         MUNICIPIO         ENTIDAD                INCUMPLIMIENTO  CUMPLIO?
# ...

# %%
df_clean_v2 = df_clean.drop(['INCUMPLIMIENTO'], axis=1)

# %%
df_clean_v2.head()
# Out:
#   TIPO DE PRODUCTO                           DESCRIPCION DEL PRODUCTO  \
# 0          MUÑECOS  EN EMPAQUE DE CARTON ESTAMPADO Y PLASTICO RIGI...
# 1   ROPA CABALLERO  CAMISA PARA CABALLERO EN COLOR AZUL MARINO DE ...
# 2           BRANDY  UNA BOTELLA BRANDY DE LA MARCA TORRES 10 CON L...
# 3           BRANDY  ENVASE DE VIDRIO CONTENIDO BRANDY DE LA MARCA ...
# 4           BRANDY  BOTELLA DE VIDRIO CONTENIDO BRANDY 100% UVA GR...
#
#                                RAZON SOCIAL VISITADA        GIRO COMERCIAL  \
# 0              JULIO CEPEDA JUGUETERIAS S.A. DE C.V.            JUGUETERIA
# 1                           C&A DE MEXICO S. DE R.L.  TIENDA DEPARTAMENTAL
# 2                             ASFEIXAS  S.A. DE C.V.                 MOTEL
# 3     MOTEL VILLA MIRO- MIRO HOTELERIA  S.A. DE C.V.                 MOTEL
# 4  MOTEL LUA- COMPAÑIA HOTELERA PESCADORES  S.A. ...                 MOTEL
#
#         MUNICIPIO         ENTIDAD  CUMPLIO?
# 0  AGUASCALIENTES  AGUASCALIENTES      True
# ...

# %%
df_clean_v2.to_csv('Tiendas_limpio.csv')
